# %%
# FILE 1
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 1, figsize=(9, 5), sharey=True)
axs.bar('Sorted Index', 19.34, label='Sorted Index')
axs.bar('Hash Table', 7.74, label='Hash Table')
axs.bar('Suffix Array', 5.47, label='Suffix Array')
axs.bar('Suffix Tree', 122.27, label='Suffix Tree')

axs.legend(loc=2, prop={'size': 10})
plt.xlabel("Algorithms")
plt.ylabel("memory [GB]")

fig.suptitle('Memory Consumption - Canis lupus familiaris genome, chromosome 1')
# Out:
# Text(0.5,0.98,'Memory Consumption - Canis lupus familiaris genome, chromosome 1')

# %%
# FILE2
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 1, figsize=(9, 5), sharey=True)
axs.bar('Sorted Index', 86.75, label='Sorted Index')
axs.bar('Hash Table', 31.02, label='Hash Table')
axs.bar('Suffix Array', 0, label='Suffix Array') # not tested, creation time too long
axs.bar('Suffix Tree', 0, label='Suffix Tree') # not tested, creation time too long

axs.legend(loc=1, prop={'size': 10})
plt.xlabel("Algorithms")
plt.ylabel("memory [GB]")

fig.suptitle('Memory Consumption - Phoenix dactylifera genome')
# Out:
# Text(0.5,0.98,'Memory Consumption - Phoenix dactylifera genome')

# %%
# FILE 3
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 1, figsize=(9, 5), sharey=True)
axs.bar('Sorted Index', 7.7, label='Sorted Index')
axs.bar('Hash Table', 4.76, label='Hash Table')
axs.bar('Suffix Array', 1.26, label='Suffix Array')
axs.bar('Suffix Tree', 35.66, label='Suffix Tree')

axs.legend(loc=2, prop={'size': 10})
plt.xlabel("Algorithms")
plt.ylabel("memory [GB]")

fig.suptitle('Memory Consumption - Ananascomosus genome, chromosome 1')
# Out:
# Text(0.5,0.98,'Memory Consumption - Ananascomosus genome, chromosome 1')
